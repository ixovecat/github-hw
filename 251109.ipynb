# %% [markdown]
# <a href="https://colab.research.google.com/github/ixovecat/github-hw/blob/main/251109.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#25
keys = input().split()
values = list(map(int,input().split()))

data = dict(zip(keys, values))
result = {k: data[k] for k in list(data.keys())[1::2]}

print(result)
# Out:
# alpha bravo Charlie delta echo foxtrot golt
# 30 40 50 60 70 80 90
# {'bravo': 40, 'delta': 60, 'foxtrot': 80}

# %%
#26
park = {'korean': 94, 'english': 91, 'mathematics':89, 'science':83}

print('english:',park['english'])
print('science:',park['science'])
# Out:
# english: 91
# science: 83

# %%
#27
kim = {'korean': 94,'english': 91,'mathematics': 89,'science':83}
for key in kim:
    kim[key] = 100
print(kim)
# Out:
# {'korean': 100, 'english': 100, 'mathematics': 100, 'science': 100}

# %%
#28
lee = {'korean': 94, 'english': 91, 'mathematics': 89, 'science': 83}

if 'english' in lee:
   del lee['english']
print(lee)
# Out:
# {'korean': 94, 'mathematics': 89, 'science': 83}

# %%
#29
lim = {'korean': 94, 'english': 91, 'mathematics': 89, 'science': 83}

for key, value in lim.items():
    print(key, value)
# Out:
# korean 94
# english 91
# mathematics 89
# science 83

# %%
#30
choi = {'korean': 94, 'english': 91, 'mathematics': 89, 'science': 83}

resuit = {k:v for k,v in choi.items() if v >= 90}
print(resuit.keys())
# Out:
# dict_keys(['korean', 'english'])

# %%
#31
yoo = {'korean': 94, 'english': 91, 'mathematics': 89, 'science': 83}
avg = sum(yoo.values()) / len(yoo)
print('평균:',avg)
# Out:
# 평균: 89.25
